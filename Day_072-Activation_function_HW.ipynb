# %% [markdown]
# # 作業目標:
#     寫出 ReLU & dReLU 一階導數
#     並列印

# %% [markdown]
# # 作業重點
#
# # Rectified Linear Unit- Relu
#
# f(x)=max(0,x)

# %%
import numpy as np
from numpy import *
import matplotlib.pylab as plt
# %matplotlib inline

# %%
def ReLU(x):
    return abs(x)*(x > 0)
def dReLU(x):
    return 1*(x > 0)

x = plt.linspace(-10,10,100)
plt.plot(x, ReLU(x), 'b', label='linspace(-10,10,100)') # r:red, b:blue
plt.plot(x, dReLU(x), 'r', label='linspace(-10,10,100)')
plt.grid()
plt.title('ReLU Function')
plt.text(4, 0.8, r'$\sigma(x)=\max(0,x)$', fontsize=15)
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(1))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(0.1))
plt.show()
